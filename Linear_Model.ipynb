# %% [markdown]
# ### Import Packages

# %%
library(tidyr)

# %% [markdown]
# ### Import Data

# %%
data=read.delim("Integrated_Data_Formatted.txt", header = TRUE, sep = "\t", dec = ".")
data_f <- data[,-1]
rownames(data_f) <- data[,1]

# %% [markdown]
# ### Functions

# %%
# extract p-value from model
overall_p <- function(my_model) {
    f <- summary(my_model)$fstatistic
    p <- pf(f[1],f[2],f[3],lower.tail=F)
    attributes(p) <- NULL
    return(p)
}

# %% [markdown]
# ### Univariate Regression Model

# %%
# test univariate
data_f_covar=data_f[!is.na(data_f$income_fy23),]
covar=c(data_f_covar$income_fy23)
depVar=c(data_f_covar$Density_Diff_2022_2016)

# %%
# test univariate
p_val_list=list()
model <- lm(depVar ~ covar)
summary(model)
p_val=overall_p(model)
p_val_list=append(p_val_list,p_val)
# Out:
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.598   0.162   0.468   0.888   2.872
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03565    0.80162   0.044    0.965
# covar       -0.18641    0.27435  -0.679    0.498
#
# Residual standard error: 3.885 on 184 degrees of freedom
# Multiple R-squared:  0.002503,	Adjusted R-squared:  -0.002918
# F-statistic: 0.4617 on 1 and 184 DF,  p-value: 0.4977

# %%
# for(i in 1:ncol(data_f)) {       # for-loop over columns
#     data_f_covar=data_f[!is.na(data_f[ , i]),]
#     covar = c(data_f_covar[ , i])
#     print(covar)
# }

# %%
colFactors=colnames(data_f)

# %%
# run univariate model
p_val_list=list()
storage <- list()
for (i in colnames(data_f)) {
# for(i in 1:ncol(data_f)) {
    data_f_covar=data_f[!is.na(data_f$i),]
    covar=c(data_f_covar$i)
#     data_f_covar=data_f[!is.na(data_f[ , i]),]
#     colVar=colnames(data_f_covar)
#     print(colVar)
    covar = c(data_f_covar[ , i])
    depVar=c(data_f_covar$Density_Diff_2022_2016)
    model <- lm(depVar ~ covar)
#     storage[[i]] <- lm(Density_Diff_2022_2016 ~ get(i), data_f_covar)
    storage[[i]] <- summary(model)
#     summary(model)
    p_val=overall_p(model)
    p_val_list=append(p_val_list,p_val)
}
# Out:
# Warning message in summary.lm(model):
# “essentially perfect fit: summary may be unreliable”
# Warning message in summary.lm(my_model):
# “essentially perfect fit: summary may be unreliable”

# %%
# save storage
sink("Univariate_LM_Summaries.txt")
print(storage)
sink()  # returns output to the console
# Out:
# $income_fy23
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.598   0.162   0.468   0.888   2.872
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03565    0.80162   0.044    0.965
# covar       -0.18641    0.27435  -0.679    0.498
#
# Residual standard error: 3.885 on 184 degrees of freedom
# Multiple R-squared:  0.002503,	Adjusted R-squared:  -0.002918
# F-statistic: 0.4617 on 1 and 184 DF,  p-value: 0.4977
#
#
# $populationquartile_2021
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.434  -0.445   0.318   1.095   4.036
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -2.7883     0.6841  -4.076 6.81e-05 ***
# covar         0.9141     0.2473   3.696 0.000289 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.753 on 184 degrees of freedom
# Multiple R-squared:  0.06912,	Adjusted R-squared:  0.06406
# F-statistic: 13.66 on 1 and 184 DF,  p-value: 0.0002887
#
#
# $country_war
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.690  -0.047   0.619   0.932   2.781
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.6186     0.3156   -1.96   0.0515 .
# covar         0.7711     0.7276    1.06   0.2906
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.878 on 184 degrees of freedom
# Multiple R-squared:  0.006068,	Adjusted R-squared:  0.0006662
# F-statistic: 1.123 on 1 and 184 DF,  p-value: 0.2906
#
#
# $age0to14_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.3759 -0.1494  0.2197  0.4392  1.8721
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.741052   0.242744   3.053  0.00261 **
# covar       -0.027415   0.008356  -3.281  0.00124 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.145 on 178 degrees of freedom
#   (6 observations deleted due to missingness)
# Multiple R-squared:  0.05703,	Adjusted R-squared:  0.05173
# F-statistic: 10.77 on 1 and 178 DF,  p-value: 0.001244
#
#
# $age15to65over_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.4987 -0.0688  0.1573  0.3076  2.0632
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.23504    0.92853  -1.330    0.185
# covar        0.01939    0.01457   1.331    0.185
#
# Residual standard error: 1.173 on 178 degrees of freedom
#   (6 observations deleted due to missingness)
# Multiple R-squared:  0.009856,	Adjusted R-squared:  0.004293
# F-statistic: 1.772 on 1 and 178 DF,  p-value: 0.1849
#
#
# $age65over_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.4078 -0.1209  0.2620  0.3910  2.0349
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.45977    0.14543  -3.162 0.001845 **
# covar        0.04876    0.01269   3.844 0.000168 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.133 on 178 degrees of freedom
#   (6 observations deleted due to missingness)
# Multiple R-squared:  0.07665,	Adjusted R-squared:  0.07146
# F-statistic: 14.78 on 1 and 178 DF,  p-value: 0.0001684
#
#
# $people_per_sqkm
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.777   0.350   0.508   0.806   2.623
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.4381594  0.3008007  -1.457    0.147
# covar       -0.0001707  0.0004631  -0.369    0.713
#
# Residual standard error: 3.889 on 184 degrees of freedom
# Multiple R-squared:  0.0007375,	Adjusted R-squared:  -0.004693
# F-statistic: 0.1358 on 1 and 184 DF,  p-value: 0.7129
#
#
# $populationgrowth_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.853   0.373   0.546   0.805   2.625
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.44592    0.38586  -1.156    0.249
# covar       -0.02513    0.23712  -0.106    0.916
#
# Residual standard error: 3.89 on 184 degrees of freedom
# Multiple R-squared:  6.105e-05,	Adjusted R-squared:  -0.005373
# F-statistic: 0.01123 on 1 and 184 DF,  p-value: 0.9157
#
#
# $urbanpopulation_percentoftotal
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.623   0.296   0.506   0.863   2.674
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.163631   0.804384  -0.203    0.839
# covar       -0.005211   0.012651  -0.412    0.681
#
# Residual standard error: 3.888 on 184 degrees of freedom
# Multiple R-squared:  0.0009213,	Adjusted R-squared:  -0.004508
# F-statistic: 0.1697 on 1 and 184 DF,  p-value: 0.6809
#
#
# $urbanpopulationgrowth_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.814   0.371   0.517   0.826   2.651
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.49992    0.43192  -1.157    0.249
# covar        0.01478    0.18123   0.082    0.935
#
# Residual standard error: 3.89 on 184 degrees of freedom
# Multiple R-squared:  3.615e-05,	Adjusted R-squared:  -0.005398
# F-statistic: 0.006652 on 1 and 184 DF,  p-value: 0.9351
#
#
# $ruralpopulation_percentoftotal
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.623   0.296   0.506   0.863   2.674
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.684761   0.586854  -1.167    0.245
# covar        0.005211   0.012651   0.412    0.681
#
# Residual standard error: 3.888 on 184 degrees of freedom
# Multiple R-squared:  0.0009213,	Adjusted R-squared:  -0.004508
# F-statistic: 0.1697 on 1 and 184 DF,  p-value: 0.6809
#
#
# $ruralpopulationgrowth_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -30.0828   0.1875   0.3428   0.5963   2.4453
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.26846    0.19562  -1.372    0.172
# covar       -0.02572    0.13746  -0.187    0.852
#
# Residual standard error: 2.646 on 181 degrees of freedom
#   (3 observations deleted due to missingness)
# Multiple R-squared:  0.0001934,	Adjusted R-squared:  -0.00533
# F-statistic: 0.03501 on 1 and 181 DF,  p-value: 0.8518
#
#
# $schoolenrollment_secondary_female_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.772   0.466   0.595   0.869   2.689
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.567299   0.987469  -0.574    0.566
# covar        0.000421   0.013043   0.032    0.974
#
# Residual standard error: 4.173 on 156 degrees of freedom
#   (28 observations deleted due to missingness)
# Multiple R-squared:  6.678e-06,	Adjusted R-squared:  -0.006404
# F-statistic: 0.001042 on 1 and 156 DF,  p-value: 0.9743
#
#
# $schoolenrollment_secondary_male_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.773   0.448   0.707   0.849   2.579
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.873461   1.018044  -0.858    0.392
# covar        0.004787   0.013706   0.349    0.727
#
# Residual standard error: 4.171 on 156 degrees of freedom
#   (28 observations deleted due to missingness)
# Multiple R-squared:  0.0007815,	Adjusted R-squared:  -0.005624
# F-statistic: 0.122 on 1 and 156 DF,  p-value: 0.7273
#
#
# $gdp_percapita_lcu
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.782   0.337   0.559   0.845   2.688
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -5.266e-01  2.910e-01  -1.810    0.072 .
# covar        1.873e-08  2.037e-08   0.919    0.359
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.891 on 183 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.004595,	Adjusted R-squared:  -0.0008447
# F-statistic: 0.8447 on 1 and 183 DF,  p-value: 0.3593
#
#
# $gdpgrowth_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.643   0.278   0.558   0.868   3.201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.76770    0.35340  -2.172   0.0311 *
# covar        0.06861    0.04936   1.390   0.1662
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.88 on 183 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.01045,	Adjusted R-squared:  0.005039
# F-statistic: 1.932 on 1 and 183 DF,  p-value: 0.1662
#
#
# $deathrate_per1000
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.3175 -0.0688  0.2403  0.4920  2.3116
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.66297    0.29057  -2.282   0.0237 *
# covar        0.07150    0.03455   2.070   0.0399 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.389 on 182 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.023,	Adjusted R-squared:  0.01763
# F-statistic: 4.284 on 1 and 182 DF,  p-value: 0.03989
#
#
# $mortality_rta_per100000
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2434 -0.0029  0.1732  0.4134  2.1865
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.005373   0.189768   0.028    0.977
# covar       -0.005137   0.009525  -0.539    0.590
#
# Residual standard error: 1.384 on 181 degrees of freedom
#   (3 observations deleted due to missingness)
# Multiple R-squared:  0.001604,	Adjusted R-squared:  -0.003912
# F-statistic: 0.2908 on 1 and 181 DF,  p-value: 0.5903
#
#
# $physicians_per1000
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.656   0.089   0.740   1.029   2.635
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.0498     0.4161  -2.523   0.0125 *
# covar         0.2956     0.1567   1.887   0.0608 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.863 on 183 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.01909,	Adjusted R-squared:  0.01373
# F-statistic: 3.561 on 1 and 183 DF,  p-value: 0.06075
#
#
# $surgicalprocedures_per100000
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.605   0.464   0.998   1.188   3.054
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.033e+00  7.077e-01  -1.460    0.148
# covar        4.625e-05  8.538e-05   0.542    0.589
#
# Residual standard error: 5.167 on 97 degrees of freedom
#   (87 observations deleted due to missingness)
# Multiple R-squared:  0.003016,	Adjusted R-squared:  -0.007262
# F-statistic: 0.2934 on 1 and 97 DF,  p-value: 0.5893
#
#
# $risk_impoverishing_surgicalcare_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.8585 -0.1889  0.1277  0.4090  1.8178
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.34550    0.12038   2.870  0.00473 **
# covar       -0.01226    0.00383  -3.201  0.00169 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.102 on 141 degrees of freedom
#   (43 observations deleted due to missingness)
# Multiple R-squared:  0.06775,	Adjusted R-squared:  0.06113
# F-statistic: 10.25 on 1 and 141 DF,  p-value: 0.001693
#
#
# $risk_catastrophic_surgicalcare_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.6978 -0.1181 -0.0190  0.2902  2.0476
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.123677   0.132315   0.935    0.352
# covar       -0.001132   0.003968  -0.285    0.776
#
# Residual standard error: 1.141 on 141 degrees of freedom
#   (43 observations deleted due to missingness)
# Multiple R-squared:  0.0005774,	Adjusted R-squared:  -0.006511
# F-statistic: 0.08147 on 1 and 141 DF,  p-value: 0.7757
#
#
# $pushedbelow_60percent_poverty_healthcareexpenditure_percent
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.73038 -0.18854 -0.09907  0.18867  1.98858
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.209865   0.142427   1.473    0.143
# covar       -0.002595   0.010800  -0.240    0.810
#
# Residual standard error: 0.5815 on 127 degrees of freedom
#   (57 observations deleted due to missingness)
# Multiple R-squared:  0.0004545,	Adjusted R-squared:  -0.007416
# F-statistic: 0.05775 on 1 and 127 DF,  p-value: 0.8105
#
#
# $healthexpenditure_percentofgdp
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.666  -0.517   0.400   1.398   4.783
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.95004    0.66952   2.913  0.00403 **
# covar       -0.36721    0.09213  -3.986 9.72e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.751 on 182 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.08028,	Adjusted R-squared:  0.07523
# F-statistic: 15.89 on 1 and 182 DF,  p-value: 9.721e-05
#
#
# $healthexpenditure_percapita_usd
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.819   0.281   0.637   0.858   2.519
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.6353183  0.3366753  -1.887   0.0607 .
# covar        0.0001393  0.0001573   0.886   0.3768
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.902 on 182 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.004294,	Adjusted R-squared:  -0.001177
# F-statistic: 0.7849 on 1 and 182 DF,  p-value: 0.3768
#
#
# $outofpocketexpenditure_percentcurrenthealthexpenditure
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.588  -0.222   0.562   1.320   3.194
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.76648    0.54860  -3.220  0.00152 **
# covar        0.04062    0.01485   2.735  0.00685 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.833 on 182 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.03948,	Adjusted R-squared:  0.0342
# F-statistic:  7.48 on 1 and 182 DF,  p-value: 0.006855
#
#
# $outofpocketexpenditure_over25percenthouseholdincome_percentofpeople
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.7360 -0.2460 -0.1285  0.1839  1.9469
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.14969    0.07043   2.125   0.0353 *
# covar        0.04109    0.02348   1.750   0.0823 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6191 on 138 degrees of freedom
#   (46 observations deleted due to missingness)
# Multiple R-squared:  0.02171,	Adjusted R-squared:  0.01462
# F-statistic: 3.062 on 1 and 138 DF,  p-value: 0.08234
#
#
# $netofficialaidanddevassistance_2020usd
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -38.242   0.316   0.823   1.116   2.907
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.088e+00  4.333e-01  -2.512   0.0132 *
# covar        4.048e-10  2.859e-10   1.416   0.1591
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.386 on 139 degrees of freedom
#   (45 observations deleted due to missingness)
# Multiple R-squared:  0.01421,	Adjusted R-squared:  0.007123
# F-statistic: 2.004 on 1 and 139 DF,  p-value: 0.1591
#
#
# $Density_Diff_2022_2016
#
# Call:
# lm(formula = depVar ~ covar)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -2.394e-15 -4.192e-17  2.800e-19  3.583e-17  2.415e-15
#
# Coefficients:
#              Estimate Std. Error   t value Pr(>|t|)
# (Intercept) 1.302e-16  2.017e-17 6.458e+00 9.21e-10 ***
# covar       1.000e+00  5.174e-18 1.933e+17  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.73e-16 on 184 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:      1
# F-statistic: 3.735e+34 on 1 and 184 DF,  p-value: < 2.2e-16

# %%
# create dataframe of pvalues
uni_p_val_df <- data.frame(unlist(colnames(data_f)), unlist(p_val_list))

# %%
# get cols with p values less than 0.10
uni_p_val_df_filt <- uni_p_val_df[uni_p_val_df$unlist.p_val_list.<=0.10,]
uni_p_val_df_filt=uni_p_val_df_filt[-10,]

# %%
# save p value dataframes
write.csv(uni_p_val_df, "Univariate_LM_P_Values.csv", row.names=FALSE, quote=FALSE) 
write.csv(uni_p_val_df_filt, "Univariate_LM_P_Values_Filtered.csv", row.names=FALSE, quote=FALSE)

# %% [markdown]
# ### Multivariate Regression Model

# %%
# import data
# data_tf=read.delim("Integrated_Data_Formatted_TopFactors.txt", header = TRUE, sep = "\t", dec = ".")
# data_tf_f <- data_tf[,-1]
# rownames(data_tf_f) <- data_tf[,1]

# import scaled data
data_tf=read.delim("Integrated_Data_Formatted_TopFactors_Scaled.txt", header = TRUE, sep = "\t", dec = ".")
data_tf_f <- data_tf[,-1]
rownames(data_tf_f) <- data_tf[,1]

# %%
# create vectors
populationquartile_2021_vector=c(data_tf_f$populationquartile_2021)
age0to14_percent_vector=c(data_tf_f$age0to14_percent)
age65over_percent_vector=c(data_tf_f$age65over_percent)
deathrate_per1000_vector=c(data_tf_f$deathrate_per1000)
physicians_per1000_vector=c(data_tf_f$physicians_per1000)
risk_impoverishing_surgicalcare_percent_vector=c(data_tf_f$risk_impoverishing_surgicalcare_percent)
healthexpenditure_percentofgdp_vector=c(data_tf_f$healthexpenditure_percentofgdp)
outofpocketexpenditure_percentcurrenthealthexpenditure_vector=c(data_tf_f$outofpocketexpenditure_percentcurrenthealthexpenditure)
outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector=c(data_tf_f$outofpocketexpenditure_over25percenthouseholdincome_percentofpeople)
Density_Diff_2022_2016_vector=c(data_tf_f$Density_Diff_2022_2016)

# %%
# mv model
mvModel <- lm(Density_Diff_2022_2016_vector ~ populationquartile_2021_vector + age0to14_percent_vector + age65over_percent_vector + deathrate_per1000_vector + physicians_per1000_vector + risk_impoverishing_surgicalcare_percent_vector + healthexpenditure_percentofgdp_vector + outofpocketexpenditure_percentcurrenthealthexpenditure_vector + outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector)
summary(mvModel)
# Out:
# Call:
# lm(formula = Density_Diff_2022_2016_vector ~ populationquartile_2021_vector +
#     age0to14_percent_vector + age65over_percent_vector + deathrate_per1000_vector +
#     physicians_per1000_vector + risk_impoverishing_surgicalcare_percent_vector +
#     healthexpenditure_percentofgdp_vector + outofpocketexpenditure_percentcurrenthealthexpenditure_vector +
#     outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.56066 -0.05511  0.00186  0.04328  0.42323
#
# Coefficients:
#                                                                             Estimate
# (Intercept)                                                                 0.463325
# populationquartile_2021_vector                                              0.078030
# age0to14_percent_vector                                                    -0.069113
# age65over_percent_vector                                                    0.062975
# deathrate_per1000_vector                                                    0.004713
# physicians_per1000_vector                                                   0.145871
# risk_impoverishing_surgicalcare_percent_vector                              0.010863
# healthexpenditure_percentofgdp_vector                                       0.075611
# outofpocketexpenditure_percentcurrenthealthexpenditure_vector               0.052726
# outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector  0.095139
#                                                                            Std. Error
# (Intercept)                                                                  0.081990
# populationquartile_2021_vector                                               0.033295
# age0to14_percent_vector                                                      0.123073
# age65over_percent_vector                                                     0.142858
# deathrate_per1000_vector                                                     0.076654
# physicians_per1000_vector                                                    0.082799
# risk_impoverishing_surgicalcare_percent_vector                               0.082592
# healthexpenditure_percentofgdp_vector                                        0.080673
# outofpocketexpenditure_percentcurrenthealthexpenditure_vector                0.067703
# outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector   0.069199
#                                                                            t value
# (Intercept)                                                                  5.651
# populationquartile_2021_vector                                               2.344
# age0to14_percent_vector                                                     -0.562
# age65over_percent_vector                                                     0.441
# deathrate_per1000_vector                                                     0.061
# physicians_per1000_vector                                                    1.762
# risk_impoverishing_surgicalcare_percent_vector                               0.132
# healthexpenditure_percentofgdp_vector                                        0.937
# outofpocketexpenditure_percentcurrenthealthexpenditure_vector                0.779
# outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector   1.375
#                                                                            Pr(>|t|)
# (Intercept)                                                                1.31e-07
# populationquartile_2021_vector                                               0.0209
# age0to14_percent_vector                                                      0.5756
# age65over_percent_vector                                                     0.6602
# deathrate_per1000_vector                                                     0.9511
# physicians_per1000_vector                                                    0.0809
# risk_impoverishing_surgicalcare_percent_vector                               0.8956
# healthexpenditure_percentofgdp_vector                                        0.3507
# outofpocketexpenditure_percentcurrenthealthexpenditure_vector                0.4378
# outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector   0.1720
#
# (Intercept)                                                                ***
# populationquartile_2021_vector                                             *
# age0to14_percent_vector
# age65over_percent_vector
# deathrate_per1000_vector
# physicians_per1000_vector                                                  .
# risk_impoverishing_surgicalcare_percent_vector
# healthexpenditure_percentofgdp_vector
# outofpocketexpenditure_percentcurrenthealthexpenditure_vector
# outofpocketexpenditure_over25percenthouseholdincome_percentofpeople_vector
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1207 on 108 degrees of freedom
# Multiple R-squared:  0.2956,	Adjusted R-squared:  0.2369
# F-statistic: 5.037 on 9 and 108 DF,  p-value: 1.137e-05

# %%
# save mv model summary
mvModel_Summary=summary(mvModel)
